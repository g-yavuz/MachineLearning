# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("used_cars.csv")

# %%
df.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df.sort_values(by="price",).head()
# Out:
#               brand                    model  model_year       milage  \
# 3046        Porsche          Carrera GT Base        2005    4,400 mi.
# 229         Bugatti  Veyron 16.4 Grand Sport        2011    6,330 mi.
# 1255      Chevrolet            Corvette Base        2000   97,500 mi.
# 605   Mercedes-Benz            CLK-Class 550        2007  138,000 mi.
# 1537          Acura                   TL 3.2        2008  193,783 mi.
#
#      fuel_type                                         engine  \
# 3046  Gasoline  605.0HP 5.7L 10 Cylinder Engine Gasoline Fuel
# 229   Gasoline               8.0L W16 64V GDI DOHC Twin Turbo
# 1255  Gasoline   345.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 605   Gasoline   382.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 1537  Gasoline  258.0HP 3.2L V6 Cylinder Engine Gasoline Fuel
#
#                            transmission ext_col int_col  \
# 3046                        6-Speed M/T    Gray   Black
# ...

# %%
df.tail()
# Out:
#         brand                 model  model_year      milage fuel_type  \
# 4004  Bentley  Continental GT Speed        2023     714 mi.  Gasoline
# 4005     Audi  S4 3.0T Premium Plus        2022  10,900 mi.  Gasoline
# 4006  Porsche                Taycan        2022   2,116 mi.       NaN
# 4007     Ford          F-150 Raptor        2020  33,000 mi.  Gasoline
# 4008      BMW          X3 xDrive30i        2020  43,000 mi.  Gasoline
#
#                                              engine  \
# 4004               6.0L W12 48V PDI DOHC Twin Turbo
# 4005  349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4006                                       Electric
# 4007  450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008   248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                            transmission ext_col  int_col  \
# 4004  8-Speed Automatic with Auto-Shift   C / C  Hotspur
# 4005     Transmission w/Dual Shift Mode   Black    Black
# ...

# %%
df.describe()
# Out:
#         model_year
# count  4009.000000
# mean   2015.515590
# std       6.104816
# min    1974.000000
# 25%    2012.000000
# 50%    2017.000000
# 75%    2020.000000
# max    2024.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %%
df["fuel_type"].unique()
# Out:
# array(['E85 Flex Fuel', 'Gasoline', 'Hybrid', nan, 'Diesel',
#        'Plug-In Hybrid', '–', 'not supported'], dtype=object)

# %%
df["accident"].unique()
# Out:
# array(['At least 1 accident or damage reported', 'None reported', nan],
#       dtype=object)

# %%
df["clean_title"].unique()
# Out:
# array(['Yes', nan], dtype=object)

# %%
df.columns
# Out:
# Index(['brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       170
# engine            0
# transmission      0
# ext_col           0
# int_col           0
# accident        113
# clean_title     596
# price             0
# dtype: int64

# %%
sns.pairplot(df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %%
df[["milage","price"]].head()
# Out:
#        milage    price
# 0  51,000 mi.  $10,300
# 1  34,742 mi.  $38,005
# 2  22,372 mi.  $54,598
# 3  88,900 mi.  $15,500
# 4   9,835 mi.  $34,999

# %%
df['price'] = df['price'].astype(str).str.replace('$', '', regex=False).str.replace(',', '', regex=False)
df['milage'] = df['milage'].astype(str).str.replace('mi.', '', regex=False).str.replace(',', '', regex=False)

# %%
df[["milage","price"]].head()
# Out:
#    milage  price
# 0  51000   10300
# 1  34742   38005
# 2  22372   54598
# 3  88900   15500
# 4   9835   34999

# %%
df["price"] = df["price"].astype(float)
df["milage"] = df["milage"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   float64
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 376.0+ KB

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(20,30))
plt.subplot(3,1,1)
sns.boxplot(x=df["milage"])
plt.title("Milage Outliers")
plt.subplot(3,1,2)
sns.boxplot(x=df["price"])
plt.title("Price Outliers")
plt.subplot(3,1,3)
sns.boxplot(x=df["model_year"])
plt.title("Model Year Outliers")
plt.show()

# %%
df["fuel_type"].head()
# Out:
# 0    E85 Flex Fuel
# 1         Gasoline
# 2         Gasoline
# 3           Hybrid
# 4         Gasoline
# Name: fuel_type, dtype: object

# %%
df["fuel_type"].value_counts()
# Out:
# fuel_type
# Gasoline          3309
# Hybrid             194
# E85 Flex Fuel      139
# Diesel             116
# –                   45
# Plug-In Hybrid      34
# not supported        2
# Name: count, dtype: int64

# %%
df["fuel_type"] = df["fuel_type"].replace(["-","not supported"],np.nan)

# %%
df["fuel_type"].value_counts()
# Out:
# fuel_type
# Gasoline          3309
# Hybrid             194
# E85 Flex Fuel      139
# Diesel             116
# –                   45
# Plug-In Hybrid      34
# Name: count, dtype: int64

# %%
df["fuel_type"].unique()
# Out:
# array(['E85 Flex Fuel', 'Gasoline', 'Hybrid', nan, 'Diesel',
#        'Plug-In Hybrid', '–'], dtype=object)

# %%
df["fuel_type"] = df["fuel_type"].replace(["–","not supported"],np.nan)

# %%
df["fuel_type"].value_counts()
# Out:
# fuel_type
# Gasoline          3309
# Hybrid             194
# E85 Flex Fuel      139
# Diesel             116
# Plug-In Hybrid      34
# Name: count, dtype: int64

# %%
df["fuel_type"] = df["fuel_type"].fillna(df["fuel_type"].mode()[0])

# %%
df["fuel_type"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4009 entries, 0 to 4008
# Series name: fuel_type
# Non-Null Count  Dtype
# --------------  -----
# 4009 non-null   object
# dtypes: object(1)
# memory usage: 31.4+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   float64
#  4   fuel_type     4009 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 376.0+ KB

# %%
df["accident"].unique()
# Out:
# array(['At least 1 accident or damage reported', 'None reported', nan],
#       dtype=object)

# %%
df["accident"].value_counts()
# Out:
# accident
# None reported                             2910
# At least 1 accident or damage reported     986
# Name: count, dtype: int64

# %%
df["accident"].isna().sum()
# Out:
# np.int64(113)

# %%
df["accident"] = df["accident"].fillna(df["accident"].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   float64
#  4   fuel_type     4009 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      4009 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 376.0+ KB

# %%
df["clean_title"].unique()
# Out:
# array(['Yes', nan], dtype=object)

# %%
df["clean_title"].value_counts()
# Out:
# clean_title
# Yes    3413
# Name: count, dtype: int64

# %%
df['clean_title'] = df['clean_title'].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   float64
#  4   fuel_type     4009 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      4009 non-null   object
#  10  clean_title   4009 non-null   object
#  11  price         4009 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 376.0+ KB

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df["accident"] = np.where(df["accident"].str.contains("None reported",case=False),1,0)
#if the car has a accident report that equals 0 if not it means 1

# %%
df["accident"].value_counts()
# Out:
# accident
# 1    3023
# 0     986
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  accident clean_title  \
# 0        6-Speed A/T                   Black   Black         0         Yes
# ...

# %%
df["transmission"].unique()
# Out:
# array(['6-Speed A/T', '8-Speed Automatic', 'Automatic', '7-Speed A/T',
#        'F', 'A/T', '8-Speed A/T', 'Transmission w/Dual Shift Mode',
#        '9-Speed Automatic', '6-Speed M/T', '10-Speed A/T', '9-Speed A/T',
#        '5-Speed A/T', '1-Speed A/T', 'Automatic CVT',
#        '7-Speed Automatic with Auto-Shift', 'CVT-F', 'M/T',
#        '6-Speed Automatic with Auto-Shift', '10-Speed Automatic',
#        'CVT Transmission', '4-Speed A/T', '6-Speed Automatic',
#        '4-Speed Automatic', '7-Speed M/T',
#        '8-Speed Automatic with Auto-Shift', '5-Speed Automatic',
#        '8-SPEED AT', '1-Speed Automatic', '5-Speed M/T', 'Manual',
#        '6-Speed Manual', 'Variable', '2', '7-Speed Manual',
#        'Automatic, 9-Spd 9G-Tronic', 'Automatic, 8-Spd',
#        'Automatic, 8-Spd Sport w/Sport & Manual Modes', '–',
#        'Auto, 6-Spd w/CmdShft', 'Transmission Overdrive Switch',
#        '7-Speed Automatic', 'Automatic, 8-Spd PDK Dual-Clutch',
# ...

# %%
df["fuel_type"].unique()
# Out:
# array(['E85 Flex Fuel', 'Gasoline', 'Hybrid', 'Diesel', 'Plug-In Hybrid'],
#       dtype=object)

# %%
df["is_manuel"] = df["transmission"].astype(str).str.contains(r"Manual|M/T|\bMt\b",case=False).astype(int)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  accident clean_title  \
# 0        6-Speed A/T                   Black   Black         0         Yes
# ...

# %%
df["is_manuel"].value_counts()
# Out:
# is_manuel
# 0    3633
# 1     376
# Name: count, dtype: int64

# %%
df.drop(columns="transmission",inplace=True)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#                   ext_col int_col  accident clean_title    price  is_manuel
# 0                   Black   Black         0         Yes  10300.0          0
# ...

# %%
df["clean_title"].unique()
# Out:
# array(['Yes', 'Unknown'], dtype=object)

# %%
df["clean_title"] = np.where(df["clean_title"].str.contains("Yes",case=False),1,0)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#                   ext_col int_col  accident  clean_title    price  is_manuel
# 0                   Black   Black         0            1  10300.0          0
# ...

# %%
df.drop(columns=['model', 'engine', 'ext_col', 'int_col'], inplace=True, errors='ignore')

# %%
df.head()
# Out:
#       brand  model_year   milage      fuel_type  accident  clean_title  \
# 0      Ford        2013  51000.0  E85 Flex Fuel         0            1
# 1   Hyundai        2021  34742.0       Gasoline         0            1
# 2     Lexus        2022  22372.0       Gasoline         1            0
# 3  INFINITI        2015  88900.0         Hybrid         1            1
# 4      Audi        2021   9835.0       Gasoline         1            0
#
#      price  is_manuel
# 0  10300.0          0
# 1  38005.0          0
# 2  54598.0          0
# 3  15500.0          0
# 4  34999.0          0

# %%
df["fuel_type"].unique()
# Out:
# array(['E85 Flex Fuel', 'Gasoline', 'Hybrid', 'Diesel', 'Plug-In Hybrid'],
#       dtype=object)

# %%
df = pd.get_dummies(df,columns=["fuel_type"],drop_first=True,dtype=int)

# %%
df.head()
# Out:
#       brand  model_year   milage  accident  clean_title    price  is_manuel  \
# 0      Ford        2013  51000.0         0            1  10300.0          0
# 1   Hyundai        2021  34742.0         0            1  38005.0          0
# 2     Lexus        2022  22372.0         1            0  54598.0          0
# 3  INFINITI        2015  88900.0         1            1  15500.0          0
# 4      Audi        2021   9835.0         1            0  34999.0          0
#
#    fuel_type_E85 Flex Fuel  fuel_type_Gasoline  fuel_type_Hybrid  \
# 0                        1                   0                 0
# 1                        0                   1                 0
# 2                        0                   1                 0
# 3                        0                   0                 1
# 4                        0                   1                 0
#
#    fuel_type_Plug-In Hybrid
# 0                         0
# 1                         0
# 2                         0
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                           model_year    milage  accident  clean_title  \
# model_year                  1.000000 -0.617720  0.194561    -0.264272
# milage                     -0.617720  1.000000 -0.301174     0.253614
# accident                    0.194561 -0.301174  1.000000    -0.171904
# clean_title                -0.264272  0.253614 -0.171904     1.000000
# price                       0.199496 -0.305528  0.114088    -0.085710
# is_manuel                  -0.274433  0.029339  0.012866     0.067096
# fuel_type_E85 Flex Fuel    -0.052193  0.145688 -0.056398     0.037039
# fuel_type_Gasoline         -0.087495 -0.050707  0.021722     0.006881
# fuel_type_Hybrid            0.148721 -0.095878  0.037015    -0.065866
# fuel_type_Plug-In Hybrid    0.061706 -0.056122 -0.010345     0.031002
#
#                              price  is_manuel  fuel_type_E85 Flex Fuel  \
# model_year                0.199496  -0.274433                -0.052193
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
plt.show()

# %%
#dependent and independent features

# %%
X = df.drop("price",axis=1)
y = df["price"]

# %%
X.head()
# Out:
#       brand  model_year   milage  accident  clean_title  is_manuel  \
# 0      Ford        2013  51000.0         0            1          0
# 1   Hyundai        2021  34742.0         0            1          0
# 2     Lexus        2022  22372.0         1            0          0
# 3  INFINITI        2015  88900.0         1            1          0
# 4      Audi        2021   9835.0         1            0          0
#
#    fuel_type_E85 Flex Fuel  fuel_type_Gasoline  fuel_type_Hybrid  \
# 0                        1                   0                 0
# 1                        0                   1                 0
# 2                        0                   1                 0
# 3                        0                   0                 1
# 4                        0                   1                 0
#
#    fuel_type_Plug-In Hybrid
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# ...

# %%
y.head()
# Out:
# 0    10300.0
# 1    38005.0
# 2    54598.0
# 3    15500.0
# 4    34999.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=15)

# %%
X_train.head()
# Out:
#          brand  model_year    milage  accident  clean_title  is_manuel  \
# 1606      Ford        2018   72393.0         1            1          0
# 2035  INFINITI        2023    8600.0         1            0          0
# 1419     Dodge        2003  114000.0         0            1          0
# 2675    Toyota        2017   65000.0         0            1          0
# 2712      Ford        2021   15555.0         1            1          0
#
#       fuel_type_E85 Flex Fuel  fuel_type_Gasoline  fuel_type_Hybrid  \
# 1606                        0                   1                 0
# 2035                        0                   1                 0
# 1419                        0                   1                 0
# 2675                        0                   1                 0
# 2712                        0                   1                 0
#
#       fuel_type_Plug-In Hybrid
# 1606                         0
# 2035                         0
# 1419                         0
# ...

# %%
brand_means = y_train.groupby(X_train['brand']).mean()
X_train["brand"] = X_train["brand"].map(brand_means)
X_test['brand'] = X_test['brand'].map(brand_means)
X_test['brand'] = X_test['brand'].fillna(y_train.mean())

# %%
X_train.corr()
# Out:
#                              brand  model_year    milage  accident  \
# brand                     1.000000    0.038943 -0.160392  0.071573
# model_year                0.038943    1.000000 -0.620220  0.199054
# milage                   -0.160392   -0.620220  1.000000 -0.306922
# accident                  0.071573    0.199054 -0.306922  1.000000
# clean_title              -0.037483   -0.267304  0.260136 -0.175158
# is_manuel                -0.044159   -0.261019  0.021515  0.007736
# fuel_type_E85 Flex Fuel  -0.022282   -0.049614  0.146927 -0.050321
# fuel_type_Gasoline        0.041267   -0.079755 -0.065973  0.026256
# fuel_type_Hybrid         -0.026045    0.131845 -0.080618  0.027081
# fuel_type_Plug-In Hybrid -0.014562    0.061920 -0.052468 -0.008869
#
#                           clean_title  is_manuel  fuel_type_E85 Flex Fuel  \
# brand                       -0.037483  -0.044159                -0.022282
# model_year                  -0.267304  -0.261019                -0.049614
# ...

# %%
def correlation_for_dropping(df,treshold):
    columns_to_drop = set()
    corr = X_train.corr()
    a = X_train.columns
    for i in range(len(a)):
        for j in range(i):
            if abs(corr.iloc[i,j]>treshold):
                columns_to_drop.add(corr.columns[i])

    return columns_to_drop

# %%
columns_dropping = correlation_for_dropping(X_train,0.85)

# %%
print(columns_dropping)
# Out:
# set()

# %%
from sklearn.preprocessing import RobustScaler

# %%
scaler = RobustScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
sns.boxplot(X_train_scaled)
plt.show()

# %%
print(X_train.columns[0])
# Out:
# brand

# %%
upper_limit = X_train['brand'].quantile(0.99)
X_train['brand'] = np.where(X_train['brand'] > upper_limit, upper_limit, X_train['brand'])
X_test['brand'] = np.where(X_test['brand'] > upper_limit, upper_limit, X_test['brand'])

# %%
sns.boxplot(X_train_scaled)
plt.show()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
sns.boxplot(X_train_scaled)
plt.show()

# %%
from lazypredict.Supervised import LazyRegressor

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# C:\Users\gokhan\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] Sistem belirtilen dosyayı bulamıyor
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\gokhan\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\gokhan\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gokhan\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
print(models)
# Out:
#                                Adjusted R-Squared     R-Squared          RMSE  \
# Model
# HistGradientBoostingRegressor            0.414906      0.422210  5.716794e+04
# KNeighborsRegressor                      0.345778      0.353946  6.045081e+04
# ExtraTreesRegressor                      0.315295      0.323843  6.184312e+04
# PoissonRegressor                         0.309594      0.318213  6.210005e+04
# BaggingRegressor                         0.296807      0.305585  6.267249e+04
# GradientBoostingRegressor                0.286293      0.295203  6.313927e+04
# RidgeCV                                  0.261886      0.271101  6.420977e+04
# BayesianRidge                            0.261885      0.271100  6.420984e+04
# Ridge                                    0.261880      0.271095  6.421005e+04
# Lars                                     0.261879      0.271094  6.421010e+04
# TransformedTargetRegressor               0.261879      0.271094  6.421010e+04
# ...
